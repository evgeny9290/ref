# %%
import os
import re
import random
from collections import defaultdict

# %%
story_path = "Data\sherlock\sherlock\\"

def read_all_stories(story_path):
    stories = []
    for _, _, files in os.walk(story_path):
        for file in files:
            story = []
            with open(story_path + file) as f:
                for line in f:
                    line = line.strip()
                    if line == '----------': 
                        break
                    if line != '':
                        story.append(line)
            stories.append(story)
    
    return stories
        
stories = read_all_stories(story_path)
print("number of stories = ", len(stories))
# Out:
# number of stories =  67

# %%
def clean_txt(txt):
    cleaned_txt = []
    for line in txt:
        line = line.lower()
        line = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-\\\-\]]", "", line)
        tokens = line.split(' ')
        words = [word for word in tokens if word.isalpha()]
        cleaned_txt += words
    return cleaned_txt

cleaned_stories = [clean_txt(story) for story in stories]
print("number of stories = ", len(cleaned_stories))
# Out:
# number of stories =  67

# %%
def make_markov_proba_graph(cleaned_stories, words_in_state=2):
    markov_model = defaultdict(lambda: defaultdict(int))
    
    for clean_story in cleaned_stories:
        for i in range(len(clean_story) - words_in_state - 1):
            curr_state, next_state = "", ""
            for j in range(words_in_state):
                curr_state += clean_story[i + j] + " "
                #print(i + j + words_in_state)
                if i + j + words_in_state < len(clean_story):
                    next_state += clean_story[i + j + words_in_state] + " "

            curr_state = curr_state[:-1]
            if len(next_state.split(' ')) <= words_in_state:
                next_state = None
            else:   
                next_state = next_state[:-1]
            #print(next_state)

            markov_model[curr_state][next_state] += 1

        # calc probability for each state
        for curr_state, transition in markov_model.items():
            total = sum(transition.values())
            for state, count in transition.items():
                markov_model[curr_state][state] = count/total
        
    return markov_model

# %%
markov_graph = make_markov_proba_graph(cleaned_stories=cleaned_stories, words_in_state=3)
print(f"num states = {len(markov_graph.keys())}")
# Out:
# num states = 479128

# %%
cool_options = [(key, opt) for key, opt in markov_graph.items() if len(opt) > 3]
cool_options[:5]
# Out:
# [('the adventure of',
#   defaultdict(int,
#               {'the three gables': 5.341939419032119e-17,
#                'the three garridebs': 5.341939419032119e-17,
#                'the three students': 6.734913793315876e-05,
#                'the abbey grange': 0.0010775862068997382,
#                'the blue carbuncle': 2.1243132480085386e-15,
#                'the speckled band': 0.03125000000000213,
#                'the engineers thumb': 6.526989628369813e-12,
#                'the noble bachelor': 1.0523302822967144e-06,
#                'the beryl coronet': 2.124303251869612e-15,
#                'the copper beeches': 7.009164709117737e-14,
#                'the paradol chamber': 1.3050792806859885e-11,
#                'the man with': 1.0621632880968866e-15,
#                'black peter arthur': 6.66409261767323e-21,
#                'the brucepartington plans': 6.263902580603811e-10,
#                'the greek interpreter': 2.0879675270012177e-10,
#                'the empty house': 6.734914119559144e-05,
#                'the norwood builder': 6.94537984935036e-05,
#                'the dancing men': 6.734913834096285e-05,
#                'the solitary cyclist': 0.01569234913793316,
#                'the priory school': 7.155845905384844e-05,
#                'black peter the': 3.3674568966579386e-05,
#                'charles augustus milverton': 6.734913793368977e-05,
#                'the six napoleons': 0.00787984913793316,
#                'the golden pincenez': 6.73491640326201e-05,
#                'the missing threequarter': 6.739298502816596e-05,
#                'the second stain': 0.0020544180533415587,
#                'wisteria lodge the': 2.0879675266013726e-10,
#                'the cardboard box': 4.175935185951469e-10,
#                'the red circle': 8.419059834884631e-06,
#                'the dying detective': 4.1922472165238696e-10,
#                'the devils foot': 4.1840911348633066e-10,
#                'the mazarin stone': 3.1319354110753574e-09,
#                'the sussex vampire': 0.06250000000000006,
#                'the creeping man': 1.3598811370913137e-13,
#                'the lions mane': 1.0439789867456611e-10,
#                'the veiled lodger': 0.12500000000000006,
#                'shoscombe old place': 0.003906250000000055,
#                'the retired colourman': 1.683728448281204e-05,
#                'the musgrave ritual': 0.5000001002219335,
#                'the old russian': 9.395806179182954e-08,
#                'the naval treaty': 2.693464418205653e-07,
#                'the tired captain': 2.693464418205653e-07,
#                'black peter i': 3.3674568966579386e-05,
#                'last night brings': 5.2199984777337625e-11,
#                'wisteria lodge table': 2.0879675266013726e-10,
#                'the night neither': 1.3596140402591973e-13,
#                'wisteria lodge arthur': 0.25})),
#  ('adventure of the',
#   defaultdict(int,
#               {'three gables arthur': 2.73546411558693e-22,
#                'three garridebs arthur': 2.73546411558693e-22,
#                'three students arthur': 5.47092823117386e-22,
#                'abbey grange arthur': 1.094185646234772e-21,
#                'blue carbuncle the': 2.1846094822177885e-15,
#                'speckled band the': 2.1846094822177885e-15,
#                'engineers thumb the': 2.1846094822177885e-15,
#                'noble bachelor the': 4.369218964435575e-15,
#                'beryl coronet the': 2.1846094822177885e-15,
#                'copper beeches a': 2.188371292469544e-21,
#                'paradol chamber of': 3.773858522701346e-11,
#                'blue carbuncle i': 2.1846094822177885e-15,
#                'man with the': 2.1846751333565624e-15,
#                'speckled band on': 2.1846094822177885e-15,
#                'engineers thumb of': 2.1846094822177885e-15,
#                'beryl coronet holmes': 2.1846094822177885e-15,
#                'copper beeches to': 2.1846094822177885e-15,
#                'beryl coronet arthur': 3.282556938704317e-20,
#                'blue carbuncle arthur': 6.565113877408634e-20,
#                'brucepartington plans arthur': 1.9695341632225906e-19,
#                'greek interpreter you': 3.0189338974449764e-10,
#                None: 1.9695341632225906e-19,
#                'copper beeches the': 2.1846072938464955e-15,
#                'empty house the': 4.8225308644159946e-05,
#                'norwood builder the': 4.8225308644159946e-05,
#                'dancing men the': 4.8225308644159946e-05,
#                'solitary cyclist the': 4.8225308644159946e-05,
#                'priory school the': 4.8225308644159946e-05,
#                'six napoleons the': 4.8225308644159946e-05,
#                'three students the': 4.8225308644159946e-05,
#                'golden pincenez the': 4.8225308644159946e-05,
#                'missing threequarter the': 4.8225308644159946e-05,
#                'abbey grange the': 4.8225308644159946e-05,
#                'second stain the': 4.860991804143844e-05,
#                'cardboard box the': 3.018933895475443e-10,
#                'red circle the': 3.018933895475443e-10,
#                'brucepartington plans the': 6.037867790950886e-10,
#                'dying detective the': 3.018933895475443e-10,
#                'devils foot his': 3.018933895475443e-10,
#                'mazarin stone the': 1.221111181198006e-16,
#                'three gables the': 1.221111181198006e-16,
#                'sussex vampire the': 1.221111181198006e-16,
#                'three garridebs the': 1.221111181198006e-16,
#                'creeping man the': 1.221111181198006e-16,
#                'lions mane the': 1.221111181198006e-16,
#                'veiled lodger the': 1.221111181198006e-16,
#                'retired colourman a': 7.878136652890362e-19,
#                'musgrave ritual and': 0.5000000078491736,
#                'sign of four': 0.0625000078491735,
#                'old russian woman': 1.3343591476819793e-07,
#                'musgrave ritual i': 1.3343591476819793e-07,
#                'naval treaty and': 3.846093972784862e-07,
#                'tired captain the': 3.846093972784862e-07,
#                'empty house it': 9.645062357771999e-05,
#                'norwood builder from': 4.8225308644159946e-05,
#                'dancing men holmes': 4.8225308644159946e-05,
#                'solitary cyclist from': 4.8225308644159946e-05,
#                'priory school we': 4.8225308644159946e-05,
#                'six napoleons it': 4.8225308644159946e-05,
#                'napoleonic busts when': 0.005256558641977492,
#                'three students it': 4.8225308644159946e-05,
#                'golden pincenez when': 4.8225308644159946e-05,
#                'missing threequarter we': 4.8225308644159946e-05,
#                'abbey grange it': 4.8225308644159946e-05,
#                'second stain i': 4.8225308644159946e-05,
#                'abbey grange to': 0.001350308641977493,
#                'second stain should': 0.001350308641977493,
#                'cardboard box in': 3.018933895475443e-10,
#                'red circle table': 3.018933895475443e-10,
#                'brucepartington plans in': 3.018933895475443e-10,
#                'dying detective mrs': 3.018933895475443e-10,
#                'devils foot in': 3.018933895475443e-10,
#                'mazarin stone it': 1.221111181198006e-16,
#                'three gables i': 1.221111181198006e-16,
#                'sussex vampire holmes': 1.221111181198006e-16,
#                'three garridebs it': 1.221111181198006e-16,
#                'creeping man mr': 1.221111181198006e-16,
#                'night neither did': 2.6218044873986456e-13,
#                'lions mane it': 1.221111181198006e-16,
#                'veiled lodger when': 1.221111181198006e-16,
#                'retired colourman sherlock': 1.221111181198006e-16,
#                'cardboard box arthur': 6.066165222725579e-17,
#                'retired colourman preface': 1.2132330445451157e-16,
#                'copper beeches arthur': 1.3102916881087232e-13,
#                'creeping man arthur': 2.6205833762174474e-13,
#                'dancing men arthur': 7.861750128652339e-13,
#                'devils foot arthur': 1.5723500257304678e-12,
#                'dying detective arthur': 3.1447000514609356e-12,
#                'empty house arthur': 6.289400102921871e-12,
#                'engineers thumb arthur': 1.8868200308765627e-11,
#                'golden pincenez arthur': 7.54728012350626e-11,
#                'lions mane arthur': 1.509456024701252e-10,
#                'mazarin stone arthur': 3.924585664223255e-09,
#                'missing threequarter arthur': 6.279337062757207e-08,
#                'noble bachelor arthur': 1.5070408950617296e-06,
#                'norwood builder arthur': 3.014081790123459e-06,
#                'priory school arthur': 6.028163580246918e-06,
#                'red circle arthur': 1.2056327160493837e-05,
#                'retired colourman arthur': 2.4112654320987673e-05,
#                'second stain arthur': 0.0013020833333333333,
#                'six napoleons arthur': 0.005208333333333332,
#                'solitary cyclist arthur': 0.015625000000000007,
#                'speckled band arthur': 0.03124999999999999,
#                'sussex vampire arthur': 0.12500000000000003,
#                'veiled lodger arthur': 0.25000000000000006})),
#  ('of the three',
#   defaultdict(int,
#               {'gables arthur conan': 2.944158036750628e-08,
#                'garridebs arthur conan': 2.944158036750628e-08,
#                'garridebs we heard': 2.3523822713637513e-05,
#                'students arthur conan': 8.832474110251881e-08,
#                'men who inhabit': 0.00707931632410799,
#                'is gilchrist a': 0.00707931632410799,
#                'he is perhaps': 0.00707931632410799,
#                'gentlemen whom you': 0.00707931632410799,
#                'i entered and': 0.00707931632410799,
#                'rooms open out': 0.25013540182811017,
#                'students the adventure': 0.007079227999366887,
#                'gables the adventure': 2.3494381133270004e-05,
#                'garridebs the problem': 2.3494381133270004e-05,
#                'fugitives and gave': 0.5001347835549225,
#                'qualities necessary for': 0.12513478355492244,
#                'murderers by the': 0.005343116888255778,
#                'students it was': 0.007079227999366887,
#                'men whom we': 0.06957922799936689,
#                'gables i dont': 2.3494381133270004e-05,
#                'garridebs it may': 2.3494381133270004e-05})),
#  ('the three gables',
#   defaultdict(int,
#               {'arthur conan doyle': 0.004081632653061225,
#                'i had not': 0.1673469387755102,
#                'harrow weald so': 0.1673469387755102,
#                'was under very': 0.1673469387755102,
#                'a very different': 0.1673469387755102,
#                'the adventure of': 0.16326530612244897,
#                'i dont think': 0.16326530612244897})),
#  ('arthur conan doyle',
#   defaultdict(int,
#               {'i dont think': 6.023345402697248e-21,
#                'it may have': 6.023345402697248e-21,
#                'it was in': 2.842172147709483e-14,
#                'it was on': 2.4093381610788992e-20,
#                'table of contents': 0.3164788496251279,
#                'holmes said i': 9.637352644315597e-20,
#                'i have never': 1.9274705288631194e-19,
#                'the ideas of': 3.8549410577262387e-19,
#                'i had called': 2.384185791023336e-07,
#                'we were seated': 1.5419764230904955e-18,
#                'in the third': 3.083952846180991e-18,
#                'the illustrious client': 4.317533984653388e-17,
#                'in choosing a': 1.850371707708595e-17,
#                'it is years': 1.1102230246251573e-16,
#                'to the man': 4.440892098500627e-16,
#                'mr sherlock holmes': 8.881784197001254e-16,
#                'one summer night': 1.776356839400251e-15,
#                'holmes had been': 3.552713678800502e-15,
#                'in recording from': 7.105427357601003e-15,
#                'mrs hudson the': 1.4210854715202007e-14,
#                'of all the': 5.684341886080805e-14,
#                'it is with': 1.136868377216161e-13,
#                'when i glance': 2.273736754432322e-13,
#                'i have some': 4.547473508864644e-13,
#                'when i look': 9.094947017729288e-13,
#                'during my long': 1.8189894035458577e-12,
#                'my dear fellow': 7.27595761418343e-12,
#                'it cant hurt': 1.455191522836686e-11,
#                'but why turkish': 2.910383045673372e-11,
#                'it was nine': 5.820766091346745e-11,
#                'it is a': 1.164153218269349e-10,
#                'it was pleasant': 4.656612873077396e-10,
#                'we were fairly': 1.862645149230958e-09,
#                'an anomaly which': 3.725290298461916e-09,
#                'the july which': 7.450580596923831e-09,
#                'the lord st': 1.4901161193847663e-08,
#                'from the point': 2.9802322387695326e-08,
#                'we have had': 5.960464477539065e-08,
#                'it was some': 4.768371582031252e-07,
#                'glancing over the': 9.536743164062504e-07,
#                'sherlock holmes was': 1.907348632812501e-06,
#                'i had intended': 1.5258789062500003e-05,
#                'sherlock holmes had': 3.051757812500001e-05,
#                'i am afraid': 0.00012207031250000003,
#                'it was no': 0.00024414062500000005,
#                'from the years': 0.0004882812500000001,
#                'on glancing over': 0.0009765625000000002,
#                'shortly after my': 0.0019531250000000004,
#                'holmes had read': 0.007812500000000002,
#                'somewhere in the': 0.015625000000000003,
#                'isa whitney brother': 0.03125000000000001,
#                'when one considers': 0.125,
#                'in publishing these': 0.5}))]

# %%
def tell_story(markov_model, walk_size=100, start='my god'):
    n = 0
    curr_state = start
    next_state = None
    story = ""
    story += curr_state+" "
    while n < walk_size:
        next_state = random.choices(list(markov_model[curr_state].keys()),list(markov_model[curr_state].values()))
        curr_state = next_state[0]
        story += curr_state + " "
        n += 1
    return story

# %%
for i in range(20):
    print("{x}. {y}".format(x=i, y=tell_story(markov_graph, start="i dont think", walk_size=7)))
# Out:
# 0. i dont think we have met before councillor youll be the new captain said mcginty thats so were looking to you councillor and to
# 1. i dont think we have met before councillor youll be the new captain said mcginty thats so were looking to you councillor and to
# 2. i dont think my nerve is as good as it was your nerve walters i should not have left us a fortune we went
# 3. i dont think my nerve is as good as it was your nerve walters i should not have the impertinence to do it again
# 4. i dont think my nerve is as good as it was your nerve walters i should not have thought you had been dead this
# 5. i dont think my nerve is as good as our word our client of the morning had hurried forward to meet his visitor for
# 6. i dont think that either inspector mac or the excellent local practitioner has grasped the overwhelming importance of this incident one dumbbell watson consider
# 7. i dont think we have met before councillor youll be the new captain said mcginty thats so were looking to you councillor and to
# 8. i dont think so holmes walked across to the door of the great lions cage and then the voice of mcginty sounded dull and
# 9. i dont think so holmes walked across to the desk and dabbed a little ink from each bottle on to the blotting paper it
# 10. i dont think my nerve is as good as it was your intention to give any one the treaty to be copied never you
# 11. i dont think that fine fellow will trouble us no more the woman stood with her hand buried in her bosom and hurried away
# 12. i dont think my nerve is as good as having one to watch the others there was major sholto captain morstan and lieutenant bromley
# 13. i dont think my nerve is as good as it was your nerve walters i should not have known where his hidingplace was how
# 14. i dont think you would guess every pocket stuffed with pennies and pennies and halfpennies it was no easy matter to drag unless you
# 15. i dont think you would guess every pocket stuffed with pennies and pennies and halfpennies it was no very simple matter to unravel her
# 16. i dont think my nerve is as good as our word our client of the morning had hurried forward to meet his visitor for
# 17. i dont think so holmes walked across to the opposite parapet whipped his lens from his pocket and handed it to some sailor customer
# 18. i dont think my nerve is as good as it was your nerve walters i should not have thought you had a nerve in
# 19. i dont think my nerve is as good as it was your nerve walters i should not have thought you had done something clever

# %%
print(tell_story(markov_graph, start="i dont think", walk_size=100))
# Out:
# i dont think my nerve is as good as it was your intention to give any one the treaty to be copied never you are certain of that absolutely well since you never said so and yet here i am said holmes smiling well goodmorning mr gibson you have a good working basis however on which to draw was a barren doctrine indeed strange rumours began to be bandied aboutrumours of murdered immigrants and rifled camps in regions where indians had never been seen fresh women appeared in the harems of the elderswomen who pined and wept and bore upon their faces the traces of the treasureseekers you must remember that they were six years looking for it no wonder that the grounds look like a tangled mass torn from the mane of a lion in that great brain of his everything is pigeonholed and can be handed out in an instant again and again his concentrated hatred urged him to continue the pursuit funds were wanting however and for some years there was no news to hear except that they were hunting for the treasure at last however there was the size of itit was twice yours sir and the look of itthe great staring goggle eyes and the distant belt of savage mountains without a sign anywhere of plant or tree which might indicate the presence of moisture in all that broad landscape there was no gleam of hope north and east and west he looked with his keen twinkling eyes at the box which had been the cause of his illdoings it seemed to send a chill right down my back i was overtaken by dr mortimer driving in his dogcart over a rough moorland track which led from the outlying farmhouse of foulmire he has been in the habit
